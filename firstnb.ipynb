# %% [markdown]
# # First part Notebook!
#
# This is the first part of the project
#
# * one
# * two
#
# An equation $e^{i \pi} = -1$ that I **love!**

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.plot(np.random.rand(100));
